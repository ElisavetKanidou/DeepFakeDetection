# %%
import os
import numpy as np
import pandas as pd
import random
from PIL import Image
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import Dataset, DataLoader, Subset
import torchvision.transforms as transforms
import gc
import psutil
from IPython.display import clear_output


def clear_memory():
    """Clears memory to prevent out-of-memory errors"""
    gc.collect()
    torch.cuda.empty_cache()
    print(f"Memory Usage: {psutil.virtual_memory().percent}%")
    
clear_memory()

# Step 1: Dataset and DataLoader
class ImageDataset(Dataset):
    def __init__(self, image_dir, label, transform=None):
        self.image_paths = []
        self.labels = []
        self.transform = transform
        for file_name in os.listdir(image_dir):
            file_path = os.path.join(image_dir, file_name)
            if file_name.endswith(('.jpg', '.png', '.jpeg')):
                self.image_paths.append(file_path)
                self.labels.append(label)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = Image.open(self.image_paths[idx]).convert('RGB')
        label = self.labels[idx]
        if self.transform:
            image = self.transform(image)
        return image, label

# Transformations - more robust
transform = transforms.Compose([
    transforms.Resize((150, 150)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # ImageNet Normalization
])

# Step 3: Paths to Test/Real and Test/Fake
test_dir = "/kaggle/input/deepfake-and-real-images/Dataset/Test"
real_dir = os.path.join(test_dir, "Real")
fake_dir = os.path.join(test_dir, "Fake")

# Verify the existence of directories
if not os.path.exists(real_dir):
    raise FileNotFoundError(f"Real directory not found: {real_dir}")
if not os.path.exists(fake_dir):
    raise FileNotFoundError(f"Fake directory not found: {fake_dir}")

# Count the number of images in each directory
num_real_images = len([f for f in os.listdir(real_dir) if f.endswith(('.jpg', '.png', '.jpeg'))])
num_fake_images = len([f for f in os.listdir(fake_dir) if f.endswith(('.jpg', '.png', '.jpeg'))])

# Print information
print(f"Found {num_real_images} Real images in directory: {real_dir}")
print(f"Found {num_fake_images} Fake images in directory: {fake_dir}")

# Dataset
real_dataset = ImageDataset(real_dir, 0, transform)
fake_dataset = ImageDataset(fake_dir, 1, transform)

dataset = real_dataset + fake_dataset
labels = real_dataset.labels + fake_dataset.labels

# Display sample images before training
def display_sample_images(dataset, num_images=5):
    plt.figure(figsize=(15, 5))
    for i in range(num_images):
        idx = random.randint(0, len(dataset) - 1)
        image, label = dataset[idx]
        image = image.permute(1, 2, 0).numpy()  # Convert to HWC format
        image = (image * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406]))  # Unnormalize
        image = np.clip(image, 0, 1)  # Clip pixel values to [0, 1]
        plt.subplot(1, num_images, i + 1)
        plt.imshow(image)
        plt.title(f"Label: {label}")
        plt.axis("off")
    plt.show()
print("Sample Images Before Training:")
display_sample_images(dataset)

clear_memory()
# Step 2: Stratified 5-Fold Cross-Validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
results = []

# Step 4: CNN Model (Improved)
class ImprovedCNN(nn.Module):
    def __init__(self):
        super(ImprovedCNN, self).__init__()
        # Convolutional layers with batch norm and ReLU
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(128)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))  # Adaptive pooling layer

        # Calculate size dynamically based on output of convolutions
        test_tensor = torch.randn(1, 3, 150, 150)
        conv_output_size = self.get_conv_output_size(test_tensor)

        # Fully connected layers with ReLU and Batch Norm
        self.fc1 = nn.Linear(conv_output_size, 512)
        self.bn_fc1 = nn.BatchNorm1d(512)
        self.fc2 = nn.Linear(512, 128)
        self.bn_fc2 = nn.BatchNorm1d(128)
        self.fc3 = nn.Linear(128, 1)
        self.dropout = nn.Dropout(0.5)

    def get_conv_output_size(self, x):
        x = self.pool(torch.relu(self.bn1(self.conv1(x))))
        x = self.pool(torch.relu(self.bn2(self.conv2(x))))
        x = self.pool(torch.relu(self.bn3(self.conv3(x))))
        x = self.avgpool(x)
        x = x.view(x.size(0), -1)
        return x.size(1)

    def forward(self, x):
        # Convolutional layers with Batch Norm and ReLU
        x = self.pool(torch.relu(self.bn1(self.conv1(x))))
        x = self.pool(torch.relu(self.bn2(self.conv2(x))))
        x = self.pool(torch.relu(self.bn3(self.conv3(x))))

        x = self.avgpool(x)
        x = x.view(x.size(0), -1)  # flatten
        # Fully connected layers with Batch Norm and ReLU
        x = torch.relu(self.bn_fc1(self.fc1(x)))
        x = self.dropout(x)
        x = torch.relu(self.bn_fc2(self.fc2(x)))
        x = self.dropout(x)
        x = torch.sigmoid(self.fc3(x))
        return x

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Training and Validation
for fold, (train_idx, test_idx) in enumerate(kf.split(dataset, labels)):
    print(f"Fold {fold + 1}")
    train_subset = Subset(dataset, train_idx)
    test_subset = Subset(dataset, test_idx)

    # Split train into train and validation (5% for validation)
    val_size = int(0.05 * len(train_subset))
    train_size = len(train_subset) - val_size
    train_subset, val_subset = torch.utils.data.random_split(train_subset, [train_size, val_size])

    train_loader = DataLoader(train_subset, batch_size=32, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_subset, batch_size=32, shuffle=False, num_workers=2)
    test_loader = DataLoader(test_subset, batch_size=32, shuffle=False, num_workers=2)

    # Model, Loss, Optimizer
    model = ImprovedCNN().to(device)
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.0005)  # Reduced initial learning rate
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3,
                                  verbose=True)  # Learning Rate Scheduler

    # Early Stopping
    best_val_loss = float('inf')
    patience = 8
    patience_counter = 0
    
    # Lists to Store losses, accuracies, and learning rates
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    learning_rates = []


    for epoch in range(200):  # Increased max epochs
        model.train()
        train_loss = 0
        train_correct = 0
        train_total = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device).float()
            optimizer.zero_grad()
            outputs = model(images).squeeze()
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

            # Calculate training accuracy
            predicted = (outputs > 0.5).float()
            train_total += labels.size(0)
            train_correct += (predicted == labels).sum().item()


        train_loss /= len(train_loader)
        train_accuracy = train_correct / train_total
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)


        # Validation
        model.eval()
        val_loss = 0
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device).float()
                outputs = model(images).squeeze()
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                 # Calculate validation accuracy
                predicted = (outputs > 0.5).float()
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()
        val_loss /= len(val_loader)
        val_accuracy = val_correct / val_total
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)

        # Store learning rate
        learning_rates.append(optimizer.param_groups[0]['lr'])



        print(f"Epoch {epoch + 1}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Train Acc: {train_accuracy:.4f}, Val Acc: {val_accuracy:.4f}")

        scheduler.step(val_loss)  # Update LR scheduler based on val_loss

        # Early Stopping Check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save(model.state_dict(), f"best_model_fold{fold + 1}.pth")
        else:
            patience_counter += 1
        if patience_counter >= patience:
            print("Early stopping triggered.")
            break
    # Plotting
    epochs = range(1, len(train_losses) + 1)

    # Loss Plot
    plt.figure(figsize=(10, 5))
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.plot(epochs, val_losses, label='Validation Loss')
    plt.title(f'Training and Validation Loss - Fold {fold+1}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()


    # Learning Rate Plot
    plt.figure(figsize=(10, 5))
    plt.plot(epochs, learning_rates, label='Learning Rate')
    plt.title(f'Learning Rate over Epochs - Fold {fold+1}')
    plt.xlabel('Epoch')
    plt.ylabel('Learning Rate')
    plt.legend()
    plt.show()

    # Step 5: Evaluate on Test Set
    model.load_state_dict(torch.load(f"best_model_fold{fold + 1}.pth"))
    model.eval()
    
    preds, actuals = [], []
    # Lists to store images and predictions for visualization
    sample_images = []
    sample_predictions = []
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            outputs = model(images).squeeze()
            preds.extend((outputs > 0.5).long().cpu().numpy())
            actuals.extend(labels.numpy())
            # Store sample images and predictions for visualization
            if len(sample_images) < 5:
              sample_images.extend(images.cpu().numpy())
              sample_predictions.extend((outputs > 0.5).long().cpu().numpy())
    # Display sample predicted images
    print(f"Sample Predictions on test dataset - Fold {fold + 1}")
    plt.figure(figsize=(15, 5))
    for i, (image, pred) in enumerate(zip(sample_images,sample_predictions)):
        if i >= 5:
          break
        image = np.transpose(image, (1, 2, 0))  # Change to HWC format
        image = (image * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406]))
        image = np.clip(image, 0, 1)
        plt.subplot(1, 5, i + 1)
        plt.imshow(image)
        plt.title(f"Pred: {pred}")
        plt.axis("off")
    plt.show()


    # Metrics
    report = classification_report(actuals, preds, output_dict=True, zero_division=0)
    confusion = confusion_matrix(actuals, preds)

    #Per class metrics plot
    class_names = ['0', '1']  #Ensure names are in report
    metrics_df = pd.DataFrame(report).transpose()
    metrics_df = metrics_df[metrics_df.index.isin(class_names)]
    
    if not metrics_df.empty: # Check if the DataFrame is not empty
      metrics_df[['precision', 'recall', 'f1-score']].plot(kind='bar', figsize=(10, 6))
      plt.title(f'Per-Class Metrics - Fold {fold+1}')
      plt.xticks(rotation=0)
      plt.ylabel('Score')
      plt.show()
    else:
       print(f"No per-class metrics to plot for fold {fold+1}. Likely one class was missing in test")


    # Save Metrics
    results.append({
        "Classifier": "ImprovedCNN",
        "Set": "Test",
        "Fold": fold + 1,
        "Accuracy": report["accuracy"],
        "Precision": report["weighted avg"]["precision"],
        "Recall": report["weighted avg"]["recall"],
        "F1-score": report["weighted avg"]["f1-score"]
    })

    # Confusion Matrix Plot
    sns.heatmap(confusion, annot=True, fmt="d", cmap="Blues", xticklabels=["Real", "Fake"], yticklabels=["Real", "Fake"])
    plt.title(f"Confusion Matrix - Fold {fold + 1}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()
    
    clear_memory()
# Save Results to DataFrame
df_results = pd.DataFrame(results)
print(df_results)

# Save the model one last time, to be sure
torch.save(model.state_dict(), "final_trained_model.pth")
print("Final model saved as final_trained_model.pth")
# Out:
# Memory Usage: 6.4%
# Found 5413 Real images in directory: /kaggle/input/deepfake-and-real-images/Dataset/Test/Real
# Found 5492 Fake images in directory: /kaggle/input/deepfake-and-real-images/Dataset/Test/Fake
# Sample Images Before Training:
# Memory Usage: 6.4%
# Fold 1
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1, Train Loss: 0.7040, Val Loss: 0.6548, Train Acc: 0.5485, Val Acc: 0.5826
# Epoch 2, Train Loss: 0.6859, Val Loss: 0.6563, Train Acc: 0.5624, Val Acc: 0.5917
# Epoch 3, Train Loss: 0.6762, Val Loss: 0.6645, Train Acc: 0.5811, Val Acc: 0.5917
# Epoch 4, Train Loss: 0.6712, Val Loss: 0.6512, Train Acc: 0.5886, Val Acc: 0.6147
# Epoch 5, Train Loss: 0.6654, Val Loss: 0.6451, Train Acc: 0.5958, Val Acc: 0.6216
# Epoch 6, Train Loss: 0.6586, Val Loss: 0.6415, Train Acc: 0.6055, Val Acc: 0.6193
# Epoch 7, Train Loss: 0.6519, Val Loss: 0.6330, Train Acc: 0.6147, Val Acc: 0.6697
# Epoch 8, Train Loss: 0.6450, Val Loss: 0.6284, Train Acc: 0.6208, Val Acc: 0.6628
# Epoch 9, Train Loss: 0.6338, Val Loss: 0.6350, Train Acc: 0.6401, Val Acc: 0.6445
# Epoch 10, Train Loss: 0.6257, Val Loss: 0.7558, Train Acc: 0.6397, Val Acc: 0.5711
# Epoch 11, Train Loss: 0.6209, Val Loss: 0.6086, Train Acc: 0.6506, Val Acc: 0.6743
# Epoch 12, Train Loss: 0.6111, Val Loss: 0.5985, Train Acc: 0.6639, Val Acc: 0.6606
# Epoch 13, Train Loss: 0.5967, Val Loss: 0.7334, Train Acc: 0.6801, Val Acc: 0.6009
# Epoch 14, Train Loss: 0.5831, Val Loss: 0.5542, Train Acc: 0.6924, Val Acc: 0.7064
# Epoch 15, Train Loss: 0.5785, Val Loss: 0.6611, Train Acc: 0.6967, Val Acc: 0.6216
# Epoch 16, Train Loss: 0.5658, Val Loss: 0.6402, Train Acc: 0.7120, Val Acc: 0.6697
# Epoch 17, Train Loss: 0.5618, Val Loss: 0.5535, Train Acc: 0.7128, Val Acc: 0.6995
# Epoch 18, Train Loss: 0.5502, Val Loss: 0.5761, Train Acc: 0.7173, Val Acc: 0.6927
# Epoch 19, Train Loss: 0.5501, Val Loss: 0.5644, Train Acc: 0.7185, Val Acc: 0.7041
# Epoch 20, Train Loss: 0.5325, Val Loss: 0.7441, Train Acc: 0.7344, Val Acc: 0.5986
# Epoch 21, Train Loss: 0.5409, Val Loss: 0.5328, Train Acc: 0.7306, Val Acc: 0.7133
# Epoch 22, Train Loss: 0.5264, Val Loss: 0.5117, Train Acc: 0.7354, Val Acc: 0.7362
# Epoch 23, Train Loss: 0.5259, Val Loss: 0.7351, Train Acc: 0.7407, Val Acc: 0.5734
# Epoch 24, Train Loss: 0.5203, Val Loss: 0.6076, Train Acc: 0.7387, Val Acc: 0.6606
# Epoch 25, Train Loss: 0.5143, Val Loss: 0.4904, Train Acc: 0.7478, Val Acc: 0.7615
# Epoch 26, Train Loss: 0.5079, Val Loss: 0.4814, Train Acc: 0.7547, Val Acc: 0.7821
# Epoch 27, Train Loss: 0.5081, Val Loss: 0.5529, Train Acc: 0.7542, Val Acc: 0.7018
# Epoch 28, Train Loss: 0.5049, Val Loss: 0.4869, Train Acc: 0.7546, Val Acc: 0.7752
# Epoch 29, Train Loss: 0.4954, Val Loss: 0.5065, Train Acc: 0.7621, Val Acc: 0.7615
# Epoch 30, Train Loss: 0.4892, Val Loss: 0.4838, Train Acc: 0.7621, Val Acc: 0.7844
# Epoch 31, Train Loss: 0.4681, Val Loss: 0.4590, Train Acc: 0.7821, Val Acc: 0.7867
# Epoch 32, Train Loss: 0.4547, Val Loss: 0.4842, Train Acc: 0.7850, Val Acc: 0.7729
# Epoch 33, Train Loss: 0.4506, Val Loss: 0.4666, Train Acc: 0.7903, Val Acc: 0.7729
# Epoch 34, Train Loss: 0.4500, Val Loss: 0.4675, Train Acc: 0.7869, Val Acc: 0.7844
# Epoch 35, Train Loss: 0.4422, Val Loss: 0.4612, Train Acc: 0.7961, Val Acc: 0.7867
# Epoch 36, Train Loss: 0.4381, Val Loss: 0.4440, Train Acc: 0.7995, Val Acc: 0.7798
# Epoch 37, Train Loss: 0.4416, Val Loss: 0.4502, Train Acc: 0.7971, Val Acc: 0.7936
# Epoch 38, Train Loss: 0.4343, Val Loss: 0.4329, Train Acc: 0.8043, Val Acc: 0.7936
# Epoch 39, Train Loss: 0.4398, Val Loss: 0.4418, Train Acc: 0.7946, Val Acc: 0.7982
# Epoch 40, Train Loss: 0.4435, Val Loss: 0.4530, Train Acc: 0.7960, Val Acc: 0.7982
# Epoch 41, Train Loss: 0.4359, Val Loss: 0.4502, Train Acc: 0.7978, Val Acc: 0.7982
# Epoch 42, Train Loss: 0.4413, Val Loss: 0.4407, Train Acc: 0.7971, Val Acc: 0.7982
# Epoch 43, Train Loss: 0.4387, Val Loss: 0.4601, Train Acc: 0.8002, Val Acc: 0.7798
# Epoch 44, Train Loss: 0.4358, Val Loss: 0.4522, Train Acc: 0.8003, Val Acc: 0.8096
# Epoch 45, Train Loss: 0.4425, Val Loss: 0.4303, Train Acc: 0.8000, Val Acc: 0.8188
# Epoch 46, Train Loss: 0.4389, Val Loss: 0.4400, Train Acc: 0.7979, Val Acc: 0.8028
# Epoch 47, Train Loss: 0.4349, Val Loss: 0.4377, Train Acc: 0.8025, Val Acc: 0.8073
# Epoch 48, Train Loss: 0.4352, Val Loss: 0.4476, Train Acc: 0.7980, Val Acc: 0.7959
# Epoch 49, Train Loss: 0.4418, Val Loss: 0.4378, Train Acc: 0.7972, Val Acc: 0.7890
# Epoch 50, Train Loss: 0.4369, Val Loss: 0.4558, Train Acc: 0.7961, Val Acc: 0.8005
# Epoch 51, Train Loss: 0.4371, Val Loss: 0.4547, Train Acc: 0.7979, Val Acc: 0.7867
# Epoch 52, Train Loss: 0.4406, Val Loss: 0.4386, Train Acc: 0.7949, Val Acc: 0.8028
# Epoch 53, Train Loss: 0.4346, Val Loss: 0.4569, Train Acc: 0.7981, Val Acc: 0.7729
# Early stopping triggered.
# <ipython-input-9-070d20b71441>:288: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"best_model_fold{fold + 1}.pth"))
# Sample Predictions on test dataset - Fold 1
# Memory Usage: 6.6%
# Fold 2
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1, Train Loss: 0.6972, Val Loss: 0.6799, Train Acc: 0.5514, Val Acc: 0.5688
# Epoch 2, Train Loss: 0.6843, Val Loss: 0.6771, Train Acc: 0.5687, Val Acc: 0.5711
# Epoch 3, Train Loss: 0.6787, Val Loss: 0.6657, Train Acc: 0.5743, Val Acc: 0.6193
# Epoch 4, Train Loss: 0.6696, Val Loss: 0.6525, Train Acc: 0.5848, Val Acc: 0.6216
# Epoch 5, Train Loss: 0.6678, Val Loss: 0.6529, Train Acc: 0.5877, Val Acc: 0.6307
# Epoch 6, Train Loss: 0.6606, Val Loss: 0.6449, Train Acc: 0.6067, Val Acc: 0.6445
# Epoch 7, Train Loss: 0.6542, Val Loss: 0.6548, Train Acc: 0.6155, Val Acc: 0.5872
# Epoch 8, Train Loss: 0.6500, Val Loss: 0.6398, Train Acc: 0.6196, Val Acc: 0.6284
# Epoch 9, Train Loss: 0.6481, Val Loss: 0.6335, Train Acc: 0.6202, Val Acc: 0.6261
# Epoch 10, Train Loss: 0.6390, Val Loss: 0.6153, Train Acc: 0.6321, Val Acc: 0.6835
# Epoch 11, Train Loss: 0.6253, Val Loss: 0.6098, Train Acc: 0.6482, Val Acc: 0.6537
# Epoch 12, Train Loss: 0.6216, Val Loss: 0.6429, Train Acc: 0.6541, Val Acc: 0.6468
# Epoch 13, Train Loss: 0.6094, Val Loss: 0.6139, Train Acc: 0.6629, Val Acc: 0.6445
# Epoch 14, Train Loss: 0.5908, Val Loss: 0.6538, Train Acc: 0.6891, Val Acc: 0.6193
# Epoch 15, Train Loss: 0.5850, Val Loss: 0.5734, Train Acc: 0.6933, Val Acc: 0.7064
# Epoch 16, Train Loss: 0.5780, Val Loss: 0.6084, Train Acc: 0.6975, Val Acc: 0.6835
# Epoch 17, Train Loss: 0.5605, Val Loss: 0.5674, Train Acc: 0.7093, Val Acc: 0.7271
# Epoch 18, Train Loss: 0.5577, Val Loss: 0.5174, Train Acc: 0.7119, Val Acc: 0.7569
# Epoch 19, Train Loss: 0.5539, Val Loss: 0.5274, Train Acc: 0.7175, Val Acc: 0.7248
# Epoch 20, Train Loss: 0.5454, Val Loss: 0.5992, Train Acc: 0.7220, Val Acc: 0.6812
# Epoch 21, Train Loss: 0.5391, Val Loss: 0.4957, Train Acc: 0.7306, Val Acc: 0.7729
# Epoch 22, Train Loss: 0.5344, Val Loss: 0.6472, Train Acc: 0.7342, Val Acc: 0.6422
# Epoch 23, Train Loss: 0.5239, Val Loss: 0.5346, Train Acc: 0.7361, Val Acc: 0.7133
# Epoch 24, Train Loss: 0.5284, Val Loss: 0.4836, Train Acc: 0.7330, Val Acc: 0.7569
# Epoch 25, Train Loss: 0.5177, Val Loss: 0.4829, Train Acc: 0.7438, Val Acc: 0.7867
# Epoch 26, Train Loss: 0.5193, Val Loss: 0.4986, Train Acc: 0.7419, Val Acc: 0.7706
# Epoch 27, Train Loss: 0.5115, Val Loss: 0.4542, Train Acc: 0.7502, Val Acc: 0.7913
# Epoch 28, Train Loss: 0.5112, Val Loss: 0.4665, Train Acc: 0.7478, Val Acc: 0.7936
# Epoch 29, Train Loss: 0.5053, Val Loss: 0.4732, Train Acc: 0.7527, Val Acc: 0.7936
# Epoch 30, Train Loss: 0.5059, Val Loss: 0.4914, Train Acc: 0.7562, Val Acc: 0.7661
# Epoch 31, Train Loss: 0.5004, Val Loss: 0.4835, Train Acc: 0.7547, Val Acc: 0.7661
# Epoch 32, Train Loss: 0.4702, Val Loss: 0.4419, Train Acc: 0.7767, Val Acc: 0.7890
# Epoch 33, Train Loss: 0.4645, Val Loss: 0.4441, Train Acc: 0.7798, Val Acc: 0.8005
# Epoch 34, Train Loss: 0.4686, Val Loss: 0.4337, Train Acc: 0.7791, Val Acc: 0.8142
# Epoch 35, Train Loss: 0.4550, Val Loss: 0.4148, Train Acc: 0.7876, Val Acc: 0.7982
# Epoch 36, Train Loss: 0.4550, Val Loss: 0.4217, Train Acc: 0.7841, Val Acc: 0.8005
# Epoch 37, Train Loss: 0.4590, Val Loss: 0.4377, Train Acc: 0.7808, Val Acc: 0.8073
# Epoch 38, Train Loss: 0.4521, Val Loss: 0.4066, Train Acc: 0.7909, Val Acc: 0.8280
# Epoch 39, Train Loss: 0.4551, Val Loss: 0.4036, Train Acc: 0.7857, Val Acc: 0.8394
# Epoch 40, Train Loss: 0.4585, Val Loss: 0.4241, Train Acc: 0.7861, Val Acc: 0.8188
# Epoch 41, Train Loss: 0.4435, Val Loss: 0.4211, Train Acc: 0.7922, Val Acc: 0.8028
# Epoch 42, Train Loss: 0.4496, Val Loss: 0.4095, Train Acc: 0.7875, Val Acc: 0.8280
# Epoch 43, Train Loss: 0.4444, Val Loss: 0.4076, Train Acc: 0.7955, Val Acc: 0.8211
# Epoch 44, Train Loss: 0.4443, Val Loss: 0.4064, Train Acc: 0.7942, Val Acc: 0.8463
# Epoch 45, Train Loss: 0.4409, Val Loss: 0.3996, Train Acc: 0.7980, Val Acc: 0.8326
# Epoch 46, Train Loss: 0.4348, Val Loss: 0.4074, Train Acc: 0.7972, Val Acc: 0.8142
# Epoch 47, Train Loss: 0.4338, Val Loss: 0.4155, Train Acc: 0.7995, Val Acc: 0.8096
# Epoch 48, Train Loss: 0.4370, Val Loss: 0.4068, Train Acc: 0.7966, Val Acc: 0.8349
# Epoch 49, Train Loss: 0.4372, Val Loss: 0.4037, Train Acc: 0.7973, Val Acc: 0.8234
# Epoch 50, Train Loss: 0.4395, Val Loss: 0.3811, Train Acc: 0.7927, Val Acc: 0.8417
# Epoch 51, Train Loss: 0.4435, Val Loss: 0.3905, Train Acc: 0.7951, Val Acc: 0.8372
# Epoch 52, Train Loss: 0.4387, Val Loss: 0.3985, Train Acc: 0.7951, Val Acc: 0.8372
# Epoch 53, Train Loss: 0.4422, Val Loss: 0.3937, Train Acc: 0.7980, Val Acc: 0.8234
# Epoch 54, Train Loss: 0.4420, Val Loss: 0.4139, Train Acc: 0.7927, Val Acc: 0.8096
# Epoch 55, Train Loss: 0.4415, Val Loss: 0.4108, Train Acc: 0.7952, Val Acc: 0.8234
# Epoch 56, Train Loss: 0.4383, Val Loss: 0.3940, Train Acc: 0.7925, Val Acc: 0.8349
# Epoch 57, Train Loss: 0.4391, Val Loss: 0.4001, Train Acc: 0.7992, Val Acc: 0.8372
# Epoch 58, Train Loss: 0.4368, Val Loss: 0.4026, Train Acc: 0.8014, Val Acc: 0.8326
# Early stopping triggered.
# <ipython-input-9-070d20b71441>:288: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"best_model_fold{fold + 1}.pth"))
# Sample Predictions on test dataset - Fold 2
# Memory Usage: 6.7%
# Fold 3
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1, Train Loss: 0.7001, Val Loss: 0.6649, Train Acc: 0.5496, Val Acc: 0.5917
# Epoch 2, Train Loss: 0.6870, Val Loss: 0.6530, Train Acc: 0.5578, Val Acc: 0.6055
# Epoch 3, Train Loss: 0.6778, Val Loss: 0.6473, Train Acc: 0.5766, Val Acc: 0.6468
# Epoch 4, Train Loss: 0.6677, Val Loss: 0.6672, Train Acc: 0.5983, Val Acc: 0.6055
# Epoch 5, Train Loss: 0.6587, Val Loss: 0.6581, Train Acc: 0.6083, Val Acc: 0.5986
# Epoch 6, Train Loss: 0.6551, Val Loss: 0.6591, Train Acc: 0.6120, Val Acc: 0.6032
# Epoch 7, Train Loss: 0.6501, Val Loss: 0.6305, Train Acc: 0.6118, Val Acc: 0.6697
# Epoch 8, Train Loss: 0.6468, Val Loss: 0.6476, Train Acc: 0.6193, Val Acc: 0.6261
# Epoch 9, Train Loss: 0.6454, Val Loss: 0.6395, Train Acc: 0.6242, Val Acc: 0.6422
# Epoch 10, Train Loss: 0.6338, Val Loss: 0.6345, Train Acc: 0.6423, Val Acc: 0.6743
# Epoch 11, Train Loss: 0.6333, Val Loss: 0.6383, Train Acc: 0.6363, Val Acc: 0.6514
# Epoch 12, Train Loss: 0.6198, Val Loss: 0.6112, Train Acc: 0.6494, Val Acc: 0.6950
# Epoch 13, Train Loss: 0.6081, Val Loss: 0.6004, Train Acc: 0.6741, Val Acc: 0.6927
# Epoch 14, Train Loss: 0.6056, Val Loss: 0.6021, Train Acc: 0.6684, Val Acc: 0.7133
# Epoch 15, Train Loss: 0.5979, Val Loss: 0.5901, Train Acc: 0.6783, Val Acc: 0.7179
# Epoch 16, Train Loss: 0.5971, Val Loss: 0.5742, Train Acc: 0.6708, Val Acc: 0.7225
# Epoch 17, Train Loss: 0.5894, Val Loss: 0.5996, Train Acc: 0.6894, Val Acc: 0.7133
# Epoch 18, Train Loss: 0.5878, Val Loss: 0.5896, Train Acc: 0.6844, Val Acc: 0.7110
# Epoch 19, Train Loss: 0.5806, Val Loss: 0.5601, Train Acc: 0.6933, Val Acc: 0.7225
# Epoch 20, Train Loss: 0.5734, Val Loss: 0.5590, Train Acc: 0.6929, Val Acc: 0.7385
# Epoch 21, Train Loss: 0.5734, Val Loss: 0.5499, Train Acc: 0.6958, Val Acc: 0.7317
# Epoch 22, Train Loss: 0.5747, Val Loss: 0.5404, Train Acc: 0.6996, Val Acc: 0.7271
# Epoch 23, Train Loss: 0.5685, Val Loss: 0.5394, Train Acc: 0.7033, Val Acc: 0.7294
# Epoch 24, Train Loss: 0.5646, Val Loss: 0.5234, Train Acc: 0.7108, Val Acc: 0.7592
# Epoch 25, Train Loss: 0.5577, Val Loss: 0.5399, Train Acc: 0.7151, Val Acc: 0.7362
# Epoch 26, Train Loss: 0.5565, Val Loss: 0.5418, Train Acc: 0.7118, Val Acc: 0.7339
# Epoch 27, Train Loss: 0.5550, Val Loss: 0.5559, Train Acc: 0.7151, Val Acc: 0.7385
# Epoch 28, Train Loss: 0.5504, Val Loss: 0.5202, Train Acc: 0.7171, Val Acc: 0.7592
# Epoch 29, Train Loss: 0.5481, Val Loss: 0.5670, Train Acc: 0.7229, Val Acc: 0.7500
# Epoch 30, Train Loss: 0.5508, Val Loss: 0.5657, Train Acc: 0.7201, Val Acc: 0.7339
# Epoch 31, Train Loss: 0.5443, Val Loss: 0.5280, Train Acc: 0.7214, Val Acc: 0.7523
# Epoch 32, Train Loss: 0.5439, Val Loss: 0.5343, Train Acc: 0.7232, Val Acc: 0.7523
# Epoch 33, Train Loss: 0.5365, Val Loss: 0.5091, Train Acc: 0.7301, Val Acc: 0.7683
# Epoch 34, Train Loss: 0.5342, Val Loss: 0.5158, Train Acc: 0.7314, Val Acc: 0.7821
# Epoch 35, Train Loss: 0.5282, Val Loss: 0.5028, Train Acc: 0.7376, Val Acc: 0.7752
# Epoch 36, Train Loss: 0.5337, Val Loss: 0.5044, Train Acc: 0.7324, Val Acc: 0.7729
# Epoch 37, Train Loss: 0.5295, Val Loss: 0.4998, Train Acc: 0.7362, Val Acc: 0.7821
# Epoch 38, Train Loss: 0.5283, Val Loss: 0.5098, Train Acc: 0.7364, Val Acc: 0.7821
# Epoch 39, Train Loss: 0.5274, Val Loss: 0.5101, Train Acc: 0.7337, Val Acc: 0.7706
# Epoch 40, Train Loss: 0.5355, Val Loss: 0.5010, Train Acc: 0.7301, Val Acc: 0.7729
# Epoch 41, Train Loss: 0.5355, Val Loss: 0.5129, Train Acc: 0.7302, Val Acc: 0.7775
# Epoch 42, Train Loss: 0.5306, Val Loss: 0.4972, Train Acc: 0.7367, Val Acc: 0.7775
# Epoch 43, Train Loss: 0.5284, Val Loss: 0.5053, Train Acc: 0.7358, Val Acc: 0.7661
# Epoch 44, Train Loss: 0.5322, Val Loss: 0.5183, Train Acc: 0.7361, Val Acc: 0.7752
# Epoch 45, Train Loss: 0.5285, Val Loss: 0.4851, Train Acc: 0.7338, Val Acc: 0.7867
# Epoch 46, Train Loss: 0.5285, Val Loss: 0.5231, Train Acc: 0.7389, Val Acc: 0.7752
# Epoch 47, Train Loss: 0.5291, Val Loss: 0.5003, Train Acc: 0.7352, Val Acc: 0.7844
# Epoch 48, Train Loss: 0.5282, Val Loss: 0.5172, Train Acc: 0.7347, Val Acc: 0.7661
# Epoch 49, Train Loss: 0.5321, Val Loss: 0.4978, Train Acc: 0.7307, Val Acc: 0.7683
# Epoch 50, Train Loss: 0.5271, Val Loss: 0.5003, Train Acc: 0.7366, Val Acc: 0.7752
# Epoch 51, Train Loss: 0.5287, Val Loss: 0.4917, Train Acc: 0.7349, Val Acc: 0.7913
# Epoch 52, Train Loss: 0.5275, Val Loss: 0.5111, Train Acc: 0.7355, Val Acc: 0.7752
# Epoch 53, Train Loss: 0.5269, Val Loss: 0.5024, Train Acc: 0.7410, Val Acc: 0.7844
# Early stopping triggered.
# <ipython-input-9-070d20b71441>:288: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"best_model_fold{fold + 1}.pth"))
# Sample Predictions on test dataset - Fold 3
# Memory Usage: 6.8%
# Fold 4
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1, Train Loss: 0.7046, Val Loss: 0.6721, Train Acc: 0.5440, Val Acc: 0.5986
# Epoch 2, Train Loss: 0.6901, Val Loss: 0.6709, Train Acc: 0.5561, Val Acc: 0.5917
# Epoch 3, Train Loss: 0.6804, Val Loss: 0.6718, Train Acc: 0.5738, Val Acc: 0.5849
# Epoch 4, Train Loss: 0.6722, Val Loss: 0.6632, Train Acc: 0.5823, Val Acc: 0.6101
# Epoch 5, Train Loss: 0.6700, Val Loss: 0.6611, Train Acc: 0.5882, Val Acc: 0.6147
# Epoch 6, Train Loss: 0.6624, Val Loss: 0.6663, Train Acc: 0.5970, Val Acc: 0.5940
# Epoch 7, Train Loss: 0.6636, Val Loss: 0.6826, Train Acc: 0.5966, Val Acc: 0.5688
# Epoch 8, Train Loss: 0.6556, Val Loss: 0.6536, Train Acc: 0.6117, Val Acc: 0.6147
# Epoch 9, Train Loss: 0.6538, Val Loss: 0.6580, Train Acc: 0.6105, Val Acc: 0.6055
# Epoch 10, Train Loss: 0.6473, Val Loss: 0.6866, Train Acc: 0.6233, Val Acc: 0.5711
# Epoch 11, Train Loss: 0.6377, Val Loss: 0.6476, Train Acc: 0.6363, Val Acc: 0.6376
# Epoch 12, Train Loss: 0.6385, Val Loss: 0.6646, Train Acc: 0.6365, Val Acc: 0.6009
# Epoch 13, Train Loss: 0.6278, Val Loss: 0.6886, Train Acc: 0.6449, Val Acc: 0.5688
# Epoch 14, Train Loss: 0.6201, Val Loss: 0.6236, Train Acc: 0.6519, Val Acc: 0.6399
# Epoch 15, Train Loss: 0.6036, Val Loss: 0.6972, Train Acc: 0.6713, Val Acc: 0.6101
# Epoch 16, Train Loss: 0.5944, Val Loss: 0.6091, Train Acc: 0.6805, Val Acc: 0.6789
# Epoch 17, Train Loss: 0.5877, Val Loss: 0.6656, Train Acc: 0.6864, Val Acc: 0.6078
# Epoch 18, Train Loss: 0.5781, Val Loss: 0.6279, Train Acc: 0.6887, Val Acc: 0.6606
# Epoch 19, Train Loss: 0.5682, Val Loss: 0.6215, Train Acc: 0.7130, Val Acc: 0.6628
# Epoch 20, Train Loss: 0.5615, Val Loss: 0.5352, Train Acc: 0.7095, Val Acc: 0.7477
# Epoch 21, Train Loss: 0.5497, Val Loss: 0.6567, Train Acc: 0.7194, Val Acc: 0.6261
# Epoch 22, Train Loss: 0.5424, Val Loss: 0.6431, Train Acc: 0.7237, Val Acc: 0.6628
# Epoch 23, Train Loss: 0.5395, Val Loss: 0.5297, Train Acc: 0.7289, Val Acc: 0.6950
# Epoch 24, Train Loss: 0.5317, Val Loss: 0.5224, Train Acc: 0.7340, Val Acc: 0.7362
# Epoch 25, Train Loss: 0.5282, Val Loss: 0.5058, Train Acc: 0.7331, Val Acc: 0.7477
# Epoch 26, Train Loss: 0.5218, Val Loss: 0.7520, Train Acc: 0.7437, Val Acc: 0.6055
# Epoch 27, Train Loss: 0.5287, Val Loss: 0.5040, Train Acc: 0.7419, Val Acc: 0.7431
# Epoch 28, Train Loss: 0.5226, Val Loss: 0.5446, Train Acc: 0.7429, Val Acc: 0.7110
# Epoch 29, Train Loss: 0.5107, Val Loss: 0.5155, Train Acc: 0.7542, Val Acc: 0.7477
# Epoch 30, Train Loss: 0.5061, Val Loss: 0.8393, Train Acc: 0.7557, Val Acc: 0.5940
# Epoch 31, Train Loss: 0.5039, Val Loss: 0.4914, Train Acc: 0.7583, Val Acc: 0.7661
# Epoch 32, Train Loss: 0.5030, Val Loss: 0.4861, Train Acc: 0.7527, Val Acc: 0.7798
# Epoch 33, Train Loss: 0.5044, Val Loss: 0.4954, Train Acc: 0.7536, Val Acc: 0.7729
# Epoch 34, Train Loss: 0.4934, Val Loss: 0.5879, Train Acc: 0.7622, Val Acc: 0.6743
# Epoch 35, Train Loss: 0.4942, Val Loss: 0.5424, Train Acc: 0.7634, Val Acc: 0.7454
# Epoch 36, Train Loss: 0.4958, Val Loss: 0.5466, Train Acc: 0.7653, Val Acc: 0.7523
# Epoch 37, Train Loss: 0.4610, Val Loss: 0.4221, Train Acc: 0.7837, Val Acc: 0.8073
# Epoch 38, Train Loss: 0.4524, Val Loss: 0.4185, Train Acc: 0.7911, Val Acc: 0.8005
# Epoch 39, Train Loss: 0.4519, Val Loss: 0.4200, Train Acc: 0.7980, Val Acc: 0.8234
# Epoch 40, Train Loss: 0.4533, Val Loss: 0.4336, Train Acc: 0.7945, Val Acc: 0.7913
# Epoch 41, Train Loss: 0.4461, Val Loss: 0.4010, Train Acc: 0.8019, Val Acc: 0.8326
# Epoch 42, Train Loss: 0.4460, Val Loss: 0.4102, Train Acc: 0.7973, Val Acc: 0.8119
# Epoch 43, Train Loss: 0.4431, Val Loss: 0.4416, Train Acc: 0.8007, Val Acc: 0.7821
# Epoch 44, Train Loss: 0.4402, Val Loss: 0.4286, Train Acc: 0.8030, Val Acc: 0.8142
# Epoch 45, Train Loss: 0.4374, Val Loss: 0.3925, Train Acc: 0.8024, Val Acc: 0.8257
# Epoch 46, Train Loss: 0.4368, Val Loss: 0.4050, Train Acc: 0.7996, Val Acc: 0.8234
# Epoch 47, Train Loss: 0.4326, Val Loss: 0.3802, Train Acc: 0.8006, Val Acc: 0.8394
# Epoch 48, Train Loss: 0.4340, Val Loss: 0.3818, Train Acc: 0.8047, Val Acc: 0.8349
# Epoch 49, Train Loss: 0.4338, Val Loss: 0.3817, Train Acc: 0.8036, Val Acc: 0.8303
# Epoch 50, Train Loss: 0.4315, Val Loss: 0.3823, Train Acc: 0.8066, Val Acc: 0.8234
# Epoch 51, Train Loss: 0.4279, Val Loss: 0.4620, Train Acc: 0.8053, Val Acc: 0.7798
# Epoch 52, Train Loss: 0.4227, Val Loss: 0.4000, Train Acc: 0.8094, Val Acc: 0.8234
# Epoch 53, Train Loss: 0.4230, Val Loss: 0.3824, Train Acc: 0.8053, Val Acc: 0.8326
# Epoch 54, Train Loss: 0.4145, Val Loss: 0.3897, Train Acc: 0.8160, Val Acc: 0.8349
# Epoch 55, Train Loss: 0.4239, Val Loss: 0.3977, Train Acc: 0.8084, Val Acc: 0.8211
# Early stopping triggered.
# <ipython-input-9-070d20b71441>:288: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"best_model_fold{fold + 1}.pth"))
# Sample Predictions on test dataset - Fold 4
# Memory Usage: 6.7%
# Fold 5
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1, Train Loss: 0.7032, Val Loss: 0.6918, Train Acc: 0.5395, Val Acc: 0.5619
# Epoch 2, Train Loss: 0.6889, Val Loss: 0.6661, Train Acc: 0.5597, Val Acc: 0.5757
# Epoch 3, Train Loss: 0.6793, Val Loss: 0.6723, Train Acc: 0.5783, Val Acc: 0.5803
# Epoch 4, Train Loss: 0.6697, Val Loss: 0.6594, Train Acc: 0.5869, Val Acc: 0.5940
# Epoch 5, Train Loss: 0.6678, Val Loss: 0.6628, Train Acc: 0.5923, Val Acc: 0.5688
# Epoch 6, Train Loss: 0.6616, Val Loss: 0.6663, Train Acc: 0.6009, Val Acc: 0.6009
# Epoch 7, Train Loss: 0.6568, Val Loss: 0.6511, Train Acc: 0.6151, Val Acc: 0.6422
# Epoch 8, Train Loss: 0.6511, Val Loss: 0.6592, Train Acc: 0.6164, Val Acc: 0.5734
# Epoch 9, Train Loss: 0.6502, Val Loss: 0.6292, Train Acc: 0.6184, Val Acc: 0.6537
# Epoch 10, Train Loss: 0.6407, Val Loss: 0.6377, Train Acc: 0.6296, Val Acc: 0.6422
# Epoch 11, Train Loss: 0.6366, Val Loss: 0.6285, Train Acc: 0.6408, Val Acc: 0.6720
# Epoch 12, Train Loss: 0.6277, Val Loss: 0.6514, Train Acc: 0.6503, Val Acc: 0.6124
# Epoch 13, Train Loss: 0.6177, Val Loss: 0.6778, Train Acc: 0.6569, Val Acc: 0.6009
# Epoch 14, Train Loss: 0.6106, Val Loss: 0.6097, Train Acc: 0.6625, Val Acc: 0.6514
# Epoch 15, Train Loss: 0.6020, Val Loss: 0.6922, Train Acc: 0.6742, Val Acc: 0.5894
# Epoch 16, Train Loss: 0.5877, Val Loss: 0.7040, Train Acc: 0.6881, Val Acc: 0.5757
# Epoch 17, Train Loss: 0.5801, Val Loss: 0.6669, Train Acc: 0.6969, Val Acc: 0.6239
# Epoch 18, Train Loss: 0.5714, Val Loss: 0.5435, Train Acc: 0.7068, Val Acc: 0.7087
# Epoch 19, Train Loss: 0.5651, Val Loss: 0.5748, Train Acc: 0.7080, Val Acc: 0.7064
# Epoch 20, Train Loss: 0.5584, Val Loss: 0.6281, Train Acc: 0.7157, Val Acc: 0.6789
# Epoch 21, Train Loss: 0.5544, Val Loss: 0.5431, Train Acc: 0.7136, Val Acc: 0.7408
# Epoch 22, Train Loss: 0.5376, Val Loss: 0.5588, Train Acc: 0.7277, Val Acc: 0.7064
# Epoch 23, Train Loss: 0.5418, Val Loss: 0.5027, Train Acc: 0.7291, Val Acc: 0.7752
# Epoch 24, Train Loss: 0.5300, Val Loss: 0.5256, Train Acc: 0.7371, Val Acc: 0.7271
# Epoch 25, Train Loss: 0.5188, Val Loss: 0.6977, Train Acc: 0.7489, Val Acc: 0.6560
# Epoch 26, Train Loss: 0.5229, Val Loss: 0.5193, Train Acc: 0.7422, Val Acc: 0.7317
# Epoch 27, Train Loss: 0.5153, Val Loss: 0.6538, Train Acc: 0.7453, Val Acc: 0.6445
# Epoch 28, Train Loss: 0.4853, Val Loss: 0.5100, Train Acc: 0.7704, Val Acc: 0.7385
# Epoch 29, Train Loss: 0.4778, Val Loss: 0.4799, Train Acc: 0.7761, Val Acc: 0.7729
# Epoch 30, Train Loss: 0.4700, Val Loss: 0.4902, Train Acc: 0.7806, Val Acc: 0.7454
# Epoch 31, Train Loss: 0.4709, Val Loss: 0.5043, Train Acc: 0.7810, Val Acc: 0.7638
# Epoch 32, Train Loss: 0.4685, Val Loss: 0.4924, Train Acc: 0.7874, Val Acc: 0.7729
# Epoch 33, Train Loss: 0.4687, Val Loss: 0.5037, Train Acc: 0.7796, Val Acc: 0.7821
# Epoch 34, Train Loss: 0.4583, Val Loss: 0.5005, Train Acc: 0.7904, Val Acc: 0.7683
# Epoch 35, Train Loss: 0.4553, Val Loss: 0.4833, Train Acc: 0.7921, Val Acc: 0.7775
# Epoch 36, Train Loss: 0.4551, Val Loss: 0.4727, Train Acc: 0.7909, Val Acc: 0.7982
# Epoch 37, Train Loss: 0.4561, Val Loss: 0.4837, Train Acc: 0.7933, Val Acc: 0.7752
# Epoch 38, Train Loss: 0.4573, Val Loss: 0.4818, Train Acc: 0.7867, Val Acc: 0.7959
# Epoch 39, Train Loss: 0.4571, Val Loss: 0.4600, Train Acc: 0.7854, Val Acc: 0.7729
# Epoch 40, Train Loss: 0.4520, Val Loss: 0.4624, Train Acc: 0.7940, Val Acc: 0.7821
# Epoch 41, Train Loss: 0.4554, Val Loss: 0.4896, Train Acc: 0.7904, Val Acc: 0.7706
# Epoch 42, Train Loss: 0.4527, Val Loss: 0.4857, Train Acc: 0.7880, Val Acc: 0.7752
# Epoch 43, Train Loss: 0.4561, Val Loss: 0.4762, Train Acc: 0.7866, Val Acc: 0.7913
# Epoch 44, Train Loss: 0.4513, Val Loss: 0.4596, Train Acc: 0.7895, Val Acc: 0.7913
# Epoch 45, Train Loss: 0.4560, Val Loss: 0.4911, Train Acc: 0.7931, Val Acc: 0.7661
# Epoch 46, Train Loss: 0.4511, Val Loss: 0.4635, Train Acc: 0.7931, Val Acc: 0.7844
# Epoch 47, Train Loss: 0.4553, Val Loss: 0.4692, Train Acc: 0.7886, Val Acc: 0.8005
# Epoch 48, Train Loss: 0.4519, Val Loss: 0.4716, Train Acc: 0.7917, Val Acc: 0.7890
# Epoch 49, Train Loss: 0.4566, Val Loss: 0.4653, Train Acc: 0.7885, Val Acc: 0.7890
# Epoch 50, Train Loss: 0.4589, Val Loss: 0.4692, Train Acc: 0.7831, Val Acc: 0.7752
# Epoch 51, Train Loss: 0.4524, Val Loss: 0.4824, Train Acc: 0.7893, Val Acc: 0.7867
# Epoch 52, Train Loss: 0.4527, Val Loss: 0.4856, Train Acc: 0.7945, Val Acc: 0.7706
# Early stopping triggered.
# <ipython-input-9-070d20b71441>:288: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"best_model_fold{fold + 1}.pth"))
# Sample Predictions on test dataset - Fold 5
# Memory Usage: 6.7%
#     Classifier   Set  Fold  Accuracy  Precision    Recall  F1-score
# 0  ImprovedCNN  Test     1  0.804677   0.805612  0.804677  0.804574
# 1  ImprovedCNN  Test     2  0.796424   0.799169  0.796424  0.796043
# 2  ImprovedCNN  Test     3  0.726731   0.735466  0.726731  0.724453
# 3  ImprovedCNN  Test     4  0.805135   0.811301  0.805135  0.804303
# 4  ImprovedCNN  Test     5  0.778083   0.779083  0.778083  0.777953
# Final model saved as final_trained_model.pth
